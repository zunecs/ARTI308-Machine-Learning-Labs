# %% [markdown]
# # Lab 2 – Machine Learning Problem Identification
#
# Dataset: Netflix Movies and TV Shows (Kaggle)
#
# Student: Abdulrahman Alaamri
# Course: ARTI 308 – Machine Learning
# Semester: 2nd Semester 2025/2026

# %% [markdown]
# ## Problem Description
#
# This project aims to build a content-based recommendation system using the Netflix Movies and TV Shows dataset. Since the dataset does not include user interaction data such as ratings or watch history, this is an unsupervised learning problem.
#
# The model will learn similarities between titles based on content features such as genre, cast, director, country, rating, duration, and description. Based on these similarities, the system can recommend movies or TV shows that are similar to a selected title.

# %% [markdown]
# ## Import Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Load The Dataset

# %%
df = pd.read_csv("/netflix_titles.csv")

# %% [markdown]
# ## Dataset Shape

# %%
df.shape
# Out:
# (8807, 12)

# %% [markdown]
# ## Preview First Rows

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# ## Column Names

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# ## Data Types

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object
